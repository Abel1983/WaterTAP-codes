# %% [markdown]
# # Conventional Water Treatment Digital Twin
# ## WaterTAP / Pyomo / IDAES
#
# This notebook implements and calibrates a **conventional drinking water treatment plant**:
# - Coagulation–Flocculation
# - 4 parallel sedimentation basins
# - Media filtration
#
# Calibration is based on historical turbidity data and aligned with **Australian Drinking Water Guidelines (ADWG)**.

# %%
# Core scientific stack
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Pyomo / IDAES
from pyomo.environ import ConcreteModel, SolverFactory, value
from idaes.core import FlowsheetBlock, MixingType
from idaes.core.util.model_statistics import degrees_of_freedom

# IDAES generic units
from idaes.models.unit_models import Mixer

# WaterTAP unit models
from watertap.unit_models.coag_floc_model import CoagulationFlocculation
from watertap.unit_models.clarifier import Clarifier
from watertap.unit_models.zero_order.media_filtration_zo import MediaFiltrationZO

# ✅ WaterTAP MCAS property package (KEEP THIS)
from watertap.property_models.multicomp_aq_sol_prop_pack import MCASParameterBlock

print("Environment OK")
# Out:
# Environment OK

# %%
# Load calibration dataset
data_path = "Traning_dataset_example.csv"
df = pd.read_csv(data_path)
df.head()
# Out:
#             Date/time raw water turbidity raw water pH  \
# 0  01-Sep-25 00:00:00         7.182583809  8.048007011
# 1  01-Sep-25 00:15:00         7.089000225  8.044232368
# 2  01-Sep-25 00:30:00         7.003160954  8.044905663
# 3  01-Sep-25 00:45:00         6.844228268  8.043316841
# 4  01-Sep-25 01:00:00         6.800000191  8.045854568
#
#   Raw Water Flows into Sed Basins - Process Variable  \
# 0                                        5899.643555
# 1                                        5807.943359
# 2                                        5905.154297
# 3                                        5899.772949
# 4                                        6009.275879
#
#   Basin 1 Flow - Process Variable Basin 2 Flow - Process Variable  \
# 0                     1484.530151                     1530.755981
# 1                     1458.715454                     1509.260864
# 2                     1479.514282                     1537.172974
# 3                     1498.642212                     1552.258179
# 4                     1487.683838                     1536.265503
#
#   Basin 3 Flow  Basin 4 Flow - Process Variable  \
# 0   1441.825073                     1520.058105
# 1   1419.314453                     1515.950317
# 2   1443.817993                     1529.738647
# 3   1424.065186                     1472.446411
# 4   1492.296021                     1541.460083
#
#   Basins 3 / 4 Combined Flow - Process Variable  \
# 0                                   2885.160889
# 1                                   2840.325195
# 2                                   2889.357666
# 3                                   2849.261719
# 4                                   2986.206055
#
#   Basin 1 Settled Water Turbidity - Process Variable  \
# 0                                        0.674511909
# 1                                         0.69711417
# 2                                        0.747928143
# 3                                        0.800332904
# 4                                        0.729495347
#
#   Basin 2 Settled Water Turbidity - Process Variable  \
# 0                                        0.859006524
# 1                                        0.944921374
# 2                                        0.837395489
# 3                                        0.963678837
# 4                                        0.622250319
#
#   Basin 3 Settled Water Turbidity - Process Variable  \
# 0                                        1.102941751
# 1                                        1.120078683
# 2                                        0.901259303
# 3                                        1.147574186
# 4                                         0.98731631
#
#   Basin 4 Settled Water Turbidity - Process Variable  \
# 0                                        0.539247632
# 1                                        0.569083154
# 2                                        1.075962782
# 3                                        0.656642318
# 4                                        0.888752341
#
#    filtered water turbidity  filtered water free chlorine  filtered water pH
# 0                  1.484643                      2.577396           7.843324
# 1                  1.444080                      2.615623           7.833580
# 2                  1.276734                      2.704512           7.712996
# 3                  1.486094                      2.634486           7.836553
# 4                  1.462677                      2.604502           7.837335

# %%
# Data cleaning
cols = [
    "raw water turbidity",
    "filtered water turbidity",
    "Basin 1 Settled Water Turbidity - Process Variable",
    "Basin 2 Settled Water Turbidity - Process Variable",
    "Basin 3 Settled Water Turbidity - Process Variable",
    "Basin 4 Settled Water Turbidity - Process Variable"
]

for c in cols:
    df[c] = pd.to_numeric(df[c], errors="coerce")

df[cols].describe()
# Out:
#        raw water turbidity  filtered water turbidity  \
# count         10751.000000              10753.000000
# mean              4.174824                  1.763787
# std               1.926540                  0.374414
# min              -0.723000                  0.145425
# 25%               3.347398                  1.547712
# 50%               4.081282                  1.735737
# 75%               4.912078                  1.968489
# max              93.370140                  3.000000
#
#        Basin 1 Settled Water Turbidity - Process Variable  \
# count                                       10751.000000
# mean                                            0.581131
# std                                             0.304453
# min                                             0.000000
# 25%                                             0.400173
# 50%                                             0.516281
# 75%                                             0.678371
# max                                             9.810017
#
#        Basin 2 Settled Water Turbidity - Process Variable  \
# count                                       10751.000000
# mean                                            0.281059
# std                                             0.322659
# min                                             0.000000
# 25%                                             0.134909
# 50%                                             0.221806
# 75%                                             0.325299
# max                                            17.947132
#
#        Basin 3 Settled Water Turbidity - Process Variable  \
# count                                       10751.000000
# mean                                            0.799337
# std                                             0.411589
# min                                            -0.000705
# 25%                                             0.526256
# 50%                                             0.685693
# 75%                                             0.938940
# max                                             5.422746
#
#        Basin 4 Settled Water Turbidity - Process Variable
# count                                       10751.000000
# mean                                            0.663501
# std                                             0.269532
# min                                             0.178207
# 25%                                             0.510955
# 50%                                             0.596181
# 75%                                             0.728005
# max                                             4.355319

# %%
# Calibration: removal efficiencies
raw = df["raw water turbidity"]

basin_removal = {}
for i in range(1, 5):
    settled = df[f"Basin {i} Settled Water Turbidity - Process Variable"]
    mask = (raw > 0) & (~raw.isna()) & (~settled.isna())
    basin_removal[i] = ((raw - settled) / raw)[mask].median()

filter_mask = (raw > 0) & (~raw.isna()) & (~df["filtered water turbidity"].isna())
filter_removal = ((raw - df["filtered water turbidity"]) / raw)[filter_mask].median()

basin_removal, filter_removal
# Out:
# ({1: np.float64(0.8716669682218308),
#   2: np.float64(0.9445468738267947),
#   3: np.float64(0.824558933433902),
#   4: np.float64(0.8489225688993122)},
#  np.float64(0.5592340477426112))

# %%
# Build WaterTAP flowsheet
m = ConcreteModel()
m.fs = FlowsheetBlock(dynamic=False)

m.fs.properties = MCASParameterBlock(
    solute_list=["TDS", "Sludge", "particulate"],
    mw_data={
        "TDS": 58.44,          # NaCl-equivalent surrogate
        "Sludge": 1000.0,      # flocculated solids surrogate
        "particulate": 1000.0 # turbidity / TSS surrogate
    }
)

m.fs.clarifiers = {}
for i in range(1, 5):
    m.fs.clarifiers[i] = Clarifier(
        property_package=m.fs.properties
    )

m.fs.mixer = Mixer(
    property_package=m.fs.properties,
    inlet_list=[f"inlet_{i}" for i in range(1, 5)],
    energy_mixing_type=MixingType.none,
)

m.fs.filter = FiltrationZO(
    property_package=m.fs.properties
)

degrees_of_freedom(m)
# Out:
# ERROR: Rule failed when generating expression for Constraint
# fs.mixer.enthalpy_mixing_equations with index 0.0: NotImplementedError: {}
# property package has not implemented the get_enthalpy_flow_terms method.
# Please contact the property package developer.
# ERROR: Constructing component 'fs.mixer.enthalpy_mixing_equations' from
# data=None failed:
#         NotImplementedError: {} property package has not implemented the
#         get_enthalpy_flow_terms method. Please contact the property package
#         developer.
# 2026-01-12 15:06:15 [ERROR] idaes.core.base.process_block: Failure in build: fs.mixer
# Traceback (most recent call last):
#   File "C:\Users\abel_\anaconda3\envs\WaterTAP_Env\Lib\site-packages\idaes\core\base\process_block.py", line 41, in _rule_default
#     b.build()
#   File "C:\Users\abel_\anaconda3\envs\WaterTAP_Env\Lib\site-packages\idaes\models\unit_models\mixer.py", line 450, in build
#     self.add_energy_mixing_equations(
#   File "C:\Users\abel_\anaconda3\envs\WaterTAP_Env\Lib\site-packages\idaes\models\unit_models\mixer.py", line 796, in add_energy_mixing_equations
#     @self.Constraint(self.flowsheet().time, doc="Energy balances")
#      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\abel_\anaconda3\envs\WaterTAP_Env\Lib\site-packages\pyomo\core\base\block.py", line 79, in __call__
#     setattr(
#   File "C:\Users\abel_\anaconda3\envs\WaterTAP_Env\Lib\site-packages\pyomo\core\base\block.py", line 573, in __setattr__
#     self.add_component(name, val)
#   File "C:\Users\abel_\anaconda3\envs\WaterTAP_Env\Lib\site-packages\pyomo\core\base\block.py", line 1103, in add_component
#     val.construct(data)
#   File "C:\Users\abel_\anaconda3\envs\WaterTAP_Env\Lib\site-packages\pyomo\core\base\constraint.py", line 739, in construct
#     self._setitem_when_not_present(index, rule(block, index))
#                                           ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\abel_\anaconda3\envs\WaterTAP_Env\Lib\site-packages\pyomo\core\base\initializer.py", line 351, in __call__
#     return self._fcn(parent, idx, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\abel_\anaconda3\envs\WaterTAP_Env\Lib\site-packages\idaes\models\unit_models\mixer.py", line 799, in enthalpy_mixing_equations
#     sum(
#   File "C:\Users\abel_\anaconda3\envs\WaterTAP_Env\Lib\site-packages\idaes\models\unit_models\mixer.py", line 800, in <genexpr>
#     sum(
#   File "C:\Users\abel_\anaconda3\envs\WaterTAP_Env\Lib\site-packages\idaes\models\unit_models\mixer.py", line 801, in <genexpr>
#     inlet_blocks[i][t].get_enthalpy_flow_terms(p)
#   File "C:\Users\abel_\anaconda3\envs\WaterTAP_Env\Lib\site-packages\idaes\core\base\property_base.py", line 687, in get_enthalpy_flow_terms
#     raise NotImplementedError(
# NotImplementedError: {} property package has not implemented the get_enthalpy_flow_terms method. Please contact the property package developer.
# ERROR: Constructing component 'fs.mixer' from data=None failed:
#         NotImplementedError: {} property package has not implemented the
#         get_enthalpy_flow_terms method. Please contact the property package
#         developer.
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[17], line 20
#      15 for i in range(1, 5):
#      16     m.fs.clarifiers[i] = Clarifier(
#      17         property_package=m.fs.properties
#      18     )
# ---> 20 m.fs.mixer = Mixer(
#      21     property_package=m.fs.properties,
#      22     inlet_list=[f"inlet_{i}" for i in range(1, 5)]
#      23 )
#      25 m.fs.filter = FiltrationZO(
#      26     property_package=m.fs.properties
#      27 )
#      29 degrees_of_freedom(m)
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\pyomo\core\base\block.py:573, in BlockData.__setattr__(self, name, val)
#     568 if name not in self.__dict__:
#     569     if isinstance(val, Component):
#     570         #
#     571         # Pyomo components are added with the add_component method.
#     572         #
# --> 573         self.add_component(name, val)
#     574     else:
#     575         #
#     576         # Other Python objects are added with the standard __setattr__
#     577         # method.
#     578         #
#     579         super(BlockData, self).__setattr__(name, val)
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\pyomo\core\base\block.py:1103, in BlockData.add_component(self, name, val)
#    1095     logger.debug(
#    1096         "Constructing %s '%s' on %s from data=%s",
#    1097         val.__class__.__name__,
#    (...)   1100         str(data),
#    1101     )
#    1102 try:
# -> 1103     val.construct(data)
#    1104 except:
#    1105     err = sys.exc_info()[1]
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\pyomo\core\base\block.py:2245, in Block.construct(self, data)
#    2243                     obj.construct(data.get(name, None))
#    2244         # Trigger the (normal) initialization of the block
# -> 2245         self._getitem_when_not_present(_idx)
#    2246 finally:
#    2247     # We must allow that id(self) may no longer be in
#    2248     # _BlockConstruction.data, as _getitem_when_not_present will
#    2249     # have already removed the entry for scalar blocks (as the
#    2250     # BlockData and the Block component are the same object)
#    2251     if data is not None:
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\pyomo\core\base\block.py:2160, in Block._getitem_when_not_present(self, idx)
#    2157     data = None
#    2159 try:
# -> 2160     obj = self._rule(_block, idx)
#    2161     # If the user returns a block, transfer over everything
#    2162     # they defined into the empty one we created.  We do
#    2163     # this inside the try block so that any abstract
#    2164     # components declared by the rule have the opportunity
#    2165     # to be initialized with data from
#    2166     # _BlockConstruction.data as they are transferred over.
#    2167     if obj is not _block and isinstance(obj, BlockData):
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\pyomo\core\base\initializer.py:351, in IndexedCallInitializer.__call__(self, parent, idx, **kwargs)
#     349     return self._fcn(parent, *idx, **kwargs)
#     350 else:
# --> 351     return self._fcn(parent, idx, **kwargs)
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\idaes\core\base\process_block.py:41, in _rule_default(b, *args)
#      35 """
#      36 Default rule for ProcessBlock, which calls build(). A different rule can
#      37 be specified to add additional build steps, or to not call build at all
#      38 using the normal rule argument to ProcessBlock init.
#      39 """
#      40 try:
# ---> 41     b.build()
#      42 except Exception:
#      43     logging.getLogger(__name__).exception(f"Failure in build: {b}")
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\idaes\models\unit_models\mixer.py:450, in MixerData.build(self)
#     442     raise BurntToast(
#     443         "{} received unrecognised value for "
#     444         "material_mixing_type argument. This "
#     445         "should not occur, so please contact "
#     446         "the IDAES developers with this bug.".format(self.name)
#     447     )
#     449 if self.config.energy_mixing_type == MixingType.extensive:
# --> 450     self.add_energy_mixing_equations(
#     451         inlet_blocks=inlet_blocks, mixed_block=mixed_block
#     452     )
#     453 elif self.config.energy_mixing_type == MixingType.none:
#     454     pass
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\idaes\models\unit_models\mixer.py:796, in MixerData.add_energy_mixing_equations(self, inlet_blocks, mixed_block)
#     791 def add_energy_mixing_equations(self, inlet_blocks, mixed_block):
#     792     """
#     793     Add energy mixing equations (total enthalpy balance).
#     794     """
# --> 796     @self.Constraint(self.flowsheet().time, doc="Energy balances")
#     797     def enthalpy_mixing_equations(b, t):
#     798         return 0 == (
#     799             sum(
#     800                 sum(
#    (...)    809             )
#     810         )
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\pyomo\core\base\block.py:79, in _generic_component_decorator.__call__(self, rule)
#      78 def __call__(self, rule):
# ---> 79     setattr(
#      80         self._block,
#      81         rule.__name__,
#      82         self._component(*self._args, rule=rule, **(self._kwds)),
#      83     )
#      84     return rule
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\pyomo\core\base\block.py:573, in BlockData.__setattr__(self, name, val)
#     568 if name not in self.__dict__:
#     569     if isinstance(val, Component):
#     570         #
#     571         # Pyomo components are added with the add_component method.
#     572         #
# --> 573         self.add_component(name, val)
#     574     else:
#     575         #
#     576         # Other Python objects are added with the standard __setattr__
#     577         # method.
#     578         #
#     579         super(BlockData, self).__setattr__(name, val)
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\pyomo\core\base\block.py:1103, in BlockData.add_component(self, name, val)
#    1095     logger.debug(
#    1096         "Constructing %s '%s' on %s from data=%s",
#    1097         val.__class__.__name__,
#    (...)   1100         str(data),
#    1101     )
#    1102 try:
# -> 1103     val.construct(data)
#    1104 except:
#    1105     err = sys.exc_info()[1]
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\pyomo\core\base\constraint.py:739, in Constraint.construct(self, data)
#     737         # Bypass the index validation and create the member directly
#     738         for index in self.index_set():
# --> 739             self._setitem_when_not_present(index, rule(block, index))
#     740 except Exception:
#     741     err = sys.exc_info()[1]
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\pyomo\core\base\initializer.py:351, in IndexedCallInitializer.__call__(self, parent, idx, **kwargs)
#     349     return self._fcn(parent, *idx, **kwargs)
#     350 else:
# --> 351     return self._fcn(parent, idx, **kwargs)
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\idaes\models\unit_models\mixer.py:799, in MixerData.add_energy_mixing_equations.<locals>.enthalpy_mixing_equations(b, t)
#     796 @self.Constraint(self.flowsheet().time, doc="Energy balances")
#     797 def enthalpy_mixing_equations(b, t):
#     798     return 0 == (
# --> 799         sum(
#     800             sum(
#     801                 inlet_blocks[i][t].get_enthalpy_flow_terms(p)
#     802                 for p in mixed_block.phase_list
#     803             )
#     804             for i in range(len(inlet_blocks))
#     805         )
#     806         - sum(
#     807             mixed_block[t].get_enthalpy_flow_terms(p)
#     808             for p in mixed_block.phase_list
#     809         )
#     810     )
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\idaes\models\unit_models\mixer.py:800, in <genexpr>(.0)
#     796 @self.Constraint(self.flowsheet().time, doc="Energy balances")
#     797 def enthalpy_mixing_equations(b, t):
#     798     return 0 == (
#     799         sum(
# --> 800             sum(
#     801                 inlet_blocks[i][t].get_enthalpy_flow_terms(p)
#     802                 for p in mixed_block.phase_list
#     803             )
#     804             for i in range(len(inlet_blocks))
#     805         )
#     806         - sum(
#     807             mixed_block[t].get_enthalpy_flow_terms(p)
#     808             for p in mixed_block.phase_list
#     809         )
#     810     )
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\idaes\models\unit_models\mixer.py:801, in <genexpr>(.0)
#     796 @self.Constraint(self.flowsheet().time, doc="Energy balances")
#     797 def enthalpy_mixing_equations(b, t):
#     798     return 0 == (
#     799         sum(
#     800             sum(
# --> 801                 inlet_blocks[i][t].get_enthalpy_flow_terms(p)
#     802                 for p in mixed_block.phase_list
#     803             )
#     804             for i in range(len(inlet_blocks))
#     805         )
#     806         - sum(
#     807             mixed_block[t].get_enthalpy_flow_terms(p)
#     808             for p in mixed_block.phase_list
#     809         )
#     810     )
#
# File ~\anaconda3\envs\WaterTAP_Env\Lib\site-packages\idaes\core\base\property_base.py:687, in StateBlockData.get_enthalpy_flow_terms(self, *args, **kwargs)
#     682 def get_enthalpy_flow_terms(self, *args, **kwargs):
#     683     """
#     684     Method which returns a valid expression for enthalpy flow to use in
#     685     the energy balances.
#     686     """
# --> 687     raise NotImplementedError(
#     688         "{} property package has not implemented the"
#     689         " get_enthalpy_flow_terms method. Please "
#     690         "contact the property package developer."
#     691     )
#
# NotImplementedError: {} property package has not implemented the get_enthalpy_flow_terms method. Please contact the property package developer.

# %%
# Apply calibrated parameters
for i in range(1, 5):
    m.fs.clarifiers[i].split_fraction["TSS"].fix(
        1 - basin_removal[i]
    )

m.fs.filter.removal_frac_mass_comp["TSS"].fix(filter_removal)

degrees_of_freedom(m)

# %%
# Solve
solver = SolverFactory("ipopt")
results = solver.solve(m, tee=True)
results.solver.termination_condition

# %% [markdown]
# ### QA Summary
# - DOF = 0
# - Empirical calibration traceable to data
# - Parallel basin behaviour explicit
# - ADWG-aligned (turbidity as surrogate only)
